# %% [markdown]
# # Capstone Project 2 - DataSpark

# %%
pip install chardet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: chardet in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (5.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Detect file encoding

import chardet

def detect_encoding(file):
    with open(file, 'rb') as file:
        result = chardet.detect(file.read())
        encoding = result['encoding']
        print(f"Detected encoding for {file} : {encoding}")

list_of_csvs=[r'uncleaned_datasets/Customers.csv',r'uncleaned_datasets/Exchange_rates.csv',r'uncleaned_datasets/Products.csv',r'uncleaned_datasets/Sales.csv',r'uncleaned_datasets/Stores.csv']

for i in list_of_csvs:
    detect_encoding(i)
# Out:
# Detected encoding for <_io.BufferedReader name='uncleaned_datasets/Customers.csv'> : Windows-1252
# Detected encoding for <_io.BufferedReader name='uncleaned_datasets/Exchange_rates.csv'> : ascii
# Detected encoding for <_io.BufferedReader name='uncleaned_datasets/Products.csv'> : ascii
# Detected encoding for <_io.BufferedReader name='uncleaned_datasets/Sales.csv'> : ascii
# Detected encoding for <_io.BufferedReader name='uncleaned_datasets/Stores.csv'> : utf-8

# %% [markdown]
# ## Data Cleaning and Preparation

# %% [markdown]
# ### 1] Customers Analysis

# %%
import pandas as pd

df_customers=pd.read_csv(list_of_csvs[0], encoding='latin-1')
df_customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia    7/3/1939
# 1      Western Australia     6522      Australia      Australia   9/27/1979
# 2               Victoria     3380      Australia      Australia   5/26/1947
# 3        South Australia     5223      Australia      Australia   9/17/1957
# 4               Victoria     3698      Australia      Australia  11/19/1965
# ...                  ...      ...            ...            ...         ...
# 15261              Texas    77017  United States  North America   3/25/1936
# 15262           Virginia    22101  United States  North America   2/16/1992
# 15263     North Carolina    28405  United States  North America   11/9/1937
# 15264         California    92501  United States  North America  10/12/1937
# 15265           Michigan    48302  United States  North America   8/18/1965
#
# [15266 rows x 10 columns]

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
# Convert Birthday to Datetime format

df_customers['Birthday'] = pd.to_datetime(df_customers['Birthday'], format='%m/%d/%Y')

# %%
# Check for null values

df_customers.isna().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
# Null values from customer table

df_customers[df_customers.isnull().any(axis=1)]
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica        NaN
# 5316       732289    Male        Indro Piccio          Varcaturo        NaN
# 5372       742042    Male     Amaranto Loggia          Casaferro        NaN
# 5377       742886  Female       Edmonda Capon           Terzigno        NaN
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco        NaN
# 5485       759705    Male    Callisto Lo Duca            Casilli        NaN
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi        NaN
# 5531       766410    Male   Adelmio Beneventi             Licola        NaN
# 5631       781667  Female          Ilda Manna             Napoli        NaN
# 5695       789177    Male   Calogero Folliero      Mariglianella        NaN
#
#        State Zip Code Country Continent   Birthday
# 5304  Napoli    80035   Italy    Europe 1981-04-18
# 5316  Napoli    80014   Italy    Europe 1949-02-24
# 5372  Napoli    80034   Italy    Europe 1936-03-14
# 5377  Napoli    80040   Italy    Europe 1963-08-06
# 5378  Napoli    80038   Italy    Europe 1961-01-05
# 5485  Napoli    80047   Italy    Europe 1976-08-28
# 5525  Napoli    80045   Italy    Europe 1947-11-13
# 5531  Napoli    80078   Italy    Europe 1940-01-13
# 5631  Napoli    80134   Italy    Europe 1977-05-08
# 5695  Napoli    80030   Italy    Europe 2000-03-03

# %%
# Replacing State Code null values for Naploli as NA as it is the state code for Napoli 
df_customers.fillna('NA', inplace=True)

# Removing spaces in column names as it is better for sql
df_customers.columns = df_customers.columns.str.replace(' ', '')

# %%
# Checking for duplicated values

df_customers.duplicated().sum()
# Out:
# 0

# %%
df_customers
# Out:
#        CustomerKey  Gender               Name                 City StateCode  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST        SA
# 1              325  Female       Madison Hull           MOUNT BUDD        WA
# 2              554  Female      Claire Ferres            WINJALLOK       VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER        SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH       VIC
# ...            ...     ...                ...                  ...       ...
# 15261      2099600  Female     Denisa Duková              Houston        TX
# 15262      2099618    Male   Justin Solórzano               Mclean        VA
# 15263      2099758    Male    Svend Petrussen           Wilmington        NC
# 15264      2099862  Female       Lorenza Rush            Riverside        CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township        MI
#
#                    State ZipCode        Country      Continent   Birthday
# 0        South Australia    5523      Australia      Australia 1939-07-03
# 1      Western Australia    6522      Australia      Australia 1979-09-27
# 2               Victoria    3380      Australia      Australia 1947-05-26
# 3        South Australia    5223      Australia      Australia 1957-09-17
# 4               Victoria    3698      Australia      Australia 1965-11-19
# ...                  ...     ...            ...            ...        ...
# 15261              Texas   77017  United States  North America 1936-03-25
# 15262           Virginia   22101  United States  North America 1992-02-16
# 15263     North Carolina   28405  United States  North America 1937-11-09
# 15264         California   92501  United States  North America 1937-10-12
# 15265           Michigan   48302  United States  North America 1965-08-18
#
# [15266 rows x 10 columns]

# %%
df_customers.to_csv("cleaned_datasets/Customers.csv")

# %% [markdown]
# ### 2] Exchange Rates Analysis

# %%
# load exchange rate table

df_exchange = pd.read_csv(list_of_csvs[1], encoding='ascii')
df_exchange
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df_exchange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
# Converting Date to date format

df_exchange['Date'] = pd.to_datetime(df_exchange['Date'], format='%m/%d/%Y')

# %%
# Checking null values

df_exchange.isna().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
# Checking for duplicates

df_exchange.duplicated().sum()
# Out:
# 0

# %%
df_exchange
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df_exchange.to_csv("cleaned_datasets/Exchange_Rates.csv")

# %% [markdown]
# ### 3] Products Analysis

# %%
# load products table

df_products = pd.read_csv(list_of_csvs[2], encoding='ascii')
df_products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# 0     Silver        $6.62         $12.99              101
# 1       Blue        $6.62         $12.99              101
# 2      White        $7.40         $14.52              101
# 3     Silver       $11.00         $21.57              101
# 4        Red       $11.00         $21.57              101
# ...      ...           ...            ...             ...
# 2512     Red       $43.07        $129.99              505
# 2513   White       $43.07        $129.99              505
# 2514   White        $1.71          $3.35              505
# 2515   Black        $1.71          $3.35              505
# 2516  Silver        $1.71          $3.35              505
#
#                   Subcategory  CategoryKey     Category
# 0                     MP4&MP3            1        Audio
# 1                     MP4&MP3            1        Audio
# 2                     MP4&MP3            1        Audio
# 3                     MP4&MP3            1        Audio
# 4                     MP4&MP3            1        Audio
# ...                       ...          ...          ...
# 2512  Cell phones Accessories            5  Cell phones
# 2513  Cell phones Accessories            5  Cell phones
# 2514  Cell phones Accessories            5  Cell phones
# 2515  Cell phones Accessories            5  Cell phones
# 2516  Cell phones Accessories            5  Cell phones
#
# [2517 rows x 10 columns]

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
df_products.describe()
# Out:
#         ProductKey  SubcategoryKey  CategoryKey
# count  2517.000000     2517.000000  2517.000000
# mean   1259.000000      491.810091     4.878824
# std     726.739637      229.887134     2.299170
# min       1.000000      101.000000     1.000000
# 25%     630.000000      305.000000     3.000000
# 50%    1259.000000      406.000000     4.000000
# 75%    1888.000000      801.000000     8.000000
# max    2517.000000      808.000000     8.000000

# %%
# Checking for null values

df_products.isna().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
# Checking for duplicate values

df_products.duplicated().sum()
# Out:
# 0

# %%
# Removing dollar signs and commas, then converting into float for both columns

df_products["Unit Cost USD"] = df_products["Unit Cost USD"].str.replace("[$,]", "", regex=True).astype(float)
df_products["Unit Price USD"] = df_products["Unit Price USD"].str.replace("[$,]", "", regex=True).astype(float)

# %%
# Replacing spaces in column name

df_products.columns = df_products.columns.str.replace(' ', '')

# %%
df_products
# Out:
#       ProductKey                                    ProductName    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  UnitCostUSD  UnitPriceUSD  SubcategoryKey  \
# 0     Silver         6.62         12.99             101
# 1       Blue         6.62         12.99             101
# 2      White         7.40         14.52             101
# 3     Silver        11.00         21.57             101
# 4        Red        11.00         21.57             101
# ...      ...          ...           ...             ...
# 2512     Red        43.07        129.99             505
# 2513   White        43.07        129.99             505
# 2514   White         1.71          3.35             505
# 2515   Black         1.71          3.35             505
# 2516  Silver         1.71          3.35             505
#
#                   Subcategory  CategoryKey     Category
# 0                     MP4&MP3            1        Audio
# 1                     MP4&MP3            1        Audio
# 2                     MP4&MP3            1        Audio
# 3                     MP4&MP3            1        Audio
# 4                     MP4&MP3            1        Audio
# ...                       ...          ...          ...
# 2512  Cell phones Accessories            5  Cell phones
# 2513  Cell phones Accessories            5  Cell phones
# 2514  Cell phones Accessories            5  Cell phones
# 2515  Cell phones Accessories            5  Cell phones
# 2516  Cell phones Accessories            5  Cell phones
#
# [2517 rows x 10 columns]

# %%
df_products.to_csv("cleaned_datasets/Products.csv")

# %% [markdown]
# ### 4] Sales Analysis

# %%
# load sales table

df_sales = pd.read_csv(list_of_csvs[3], encoding='ascii')
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# 1             0        1048         2           USD
# 2             0        2007         1           USD
# 3             0        1106         7           CAD
# 4             0         373         1           CAD
# ...         ...         ...       ...           ...
# 62879        43         632         3           USD
# 62880         0          98         4           EUR
# 62881         0        1613         2           CAD
# 62882         0        1717         2           CAD
# 62883         0         464         7           CAD
#
# [62884 rows x 9 columns]

# %%
# Replacing spaces in column name

df_sales.columns = df_sales.columns.str.replace(' ', '')

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderNumber   62884 non-null  int64
#  1   LineItem      62884 non-null  int64
#  2   OrderDate     62884 non-null  object
#  3   DeliveryDate  13165 non-null  object
#  4   CustomerKey   62884 non-null  int64
#  5   StoreKey      62884 non-null  int64
#  6   ProductKey    62884 non-null  int64
#  7   Quantity      62884 non-null  int64
#  8   CurrencyCode  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
df_sales.describe()
# Out:
#         OrderNumber      LineItem   CustomerKey      StoreKey    ProductKey  \
# count  6.288400e+04  62884.000000  6.288400e+04  62884.000000  62884.000000
# mean   1.430905e+06      2.164207  1.180797e+06     31.802144   1125.859344
# std    4.532963e+05      1.365170  5.859634e+05     22.978188    709.244010
# min    3.660000e+05      1.000000  3.010000e+02      0.000000      1.000000
# 25%    1.121017e+06      1.000000  6.808580e+05      8.000000    437.000000
# 50%    1.498016e+06      2.000000  1.261200e+06     37.000000   1358.000000
# 75%    1.788010e+06      3.000000  1.686496e+06     53.000000   1650.000000
# max    2.243032e+06      7.000000  2.099937e+06     66.000000   2517.000000
#
#            Quantity
# count  62884.000000
# mean       3.144790
# std        2.256371
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max       10.000000

# %%
# Checking for null values

df_sales.isna().sum()
# Out:
# OrderNumber         0
# LineItem            0
# OrderDate           0
# DeliveryDate    49719
# CustomerKey         0
# StoreKey            0
# ProductKey          0
# Quantity            0
# CurrencyCode        0
# dtype: int64

# %%
# Change Delivery Date and Order Date to Datetime format for analysis purpose

df_sales['DeliveryDate'] = pd.to_datetime(df_sales['DeliveryDate'], errors='coerce')
df_sales['OrderDate'] = pd.to_datetime(df_sales['OrderDate'])

# %%
# filling null delivery date values to same day as order date as it was bought in store, doing this only for non-online orders or can ask the company team in real world case

df_sales.loc[df_sales['DeliveryDate'].isna() & (df_sales['StoreKey'] != 0), 'DeliveryDate'] = df_sales['OrderDate']

# %%
df_sales
# Out:
#        OrderNumber  LineItem  OrderDate DeliveryDate  CustomerKey  StoreKey  \
# 0           366000         1 2016-01-01   2016-01-01       265598        10
# 1           366001         1 2016-01-01   2016-01-13      1269051         0
# 2           366001         2 2016-01-01   2016-01-13      1269051         0
# 3           366002         1 2016-01-01   2016-01-12       266019         0
# 4           366002         2 2016-01-01   2016-01-12       266019         0
# ...            ...       ...        ...          ...          ...       ...
# 62879      2243030         1 2021-02-20   2021-02-20      1216913        43
# 62880      2243031         1 2021-02-20   2021-02-24       511229         0
# 62881      2243032         1 2021-02-20   2021-02-23       331277         0
# 62882      2243032         2 2021-02-20   2021-02-23       331277         0
# 62883      2243032         3 2021-02-20   2021-02-23       331277         0
#
#        ProductKey  Quantity CurrencyCode
# 0            1304         1          CAD
# 1            1048         2          USD
# 2            2007         1          USD
# 3            1106         7          CAD
# 4             373         1          CAD
# ...           ...       ...          ...
# 62879         632         3          USD
# 62880          98         4          EUR
# 62881        1613         2          CAD
# 62882        1717         2          CAD
# 62883         464         7          CAD
#
# [62884 rows x 9 columns]

# %%
df_sales.to_csv("cleaned_datasets/Sales.csv")

# %% [markdown]
# ### 5] Stores Analysis

# %%
# load Stores table

df_stores = pd.read_csv(list_of_csvs[4], encoding='utf-8')
df_stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# 4   12/9/2015
# ..        ...
# 62   3/6/2008
# 63   1/1/2010
# 64   1/1/2012
# 65   1/1/2014
# 66   1/1/2010
#
# [67 rows x 5 columns]

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
df_stores.describe()
# Out:
#         StoreKey  Square Meters
# count  67.000000      66.000000
# mean   33.000000    1402.196970
# std    19.485037     576.404058
# min     0.000000     245.000000
# 25%    16.500000    1108.750000
# 50%    33.000000    1347.500000
# 75%    49.500000    2000.000000
# max    66.000000    2105.000000

# %%
# Checking null values

df_stores.isna().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
# Null values are for online as there is no Square Meters(traveling distance) for it

#  repalcing with zero
df_stores.fillna(0, inplace=True)

# %%
# Replacing spaces in column name

df_stores.columns = df_stores.columns.str.replace(' ', '')

# %%
df_stores['OpenDate'] = pd.to_datetime(df_stores['OpenDate'])

# %%
df_stores
# Out:
#     StoreKey        Country                         State  SquareMeters  \
# 0          1      Australia  Australian Capital Territory         595.0
# 1          2      Australia            Northern Territory         665.0
# 2          3      Australia               South Australia        2000.0
# 3          4      Australia                      Tasmania        2000.0
# 4          5      Australia                      Victoria        2000.0
# ..       ...            ...                           ...           ...
# 62        63  United States                          Utah        2000.0
# 63        64  United States                 Washington DC        1330.0
# 64        65  United States                 West Virginia        1785.0
# 65        66  United States                       Wyoming         840.0
# 66         0         Online                        Online           0.0
#
#      OpenDate
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# 4  2015-12-09
# ..        ...
# 62 2008-03-06
# 63 2010-01-01
# 64 2012-01-01
# 65 2014-01-01
# 66 2010-01-01
#
# [67 rows x 5 columns]

# %%
df_stores.to_csv("cleaned_datasets/Stores.csv")

# %% [markdown]
# ## EDA

# %%
# Calculating birthday, age range, and store age
from datetime import datetime

def calculate_age(birthday):
    today = datetime.now()
    age = today.year - birthday.year - ((today.month, today.day) < (birthday.month, birthday.day))
    return age

# Creating true copy of df_customers
df_customers_copy = df_customers.copy()
df_customers_copy['Age'] = df_customers_copy['Birthday'].apply(calculate_age)

# Define age bins and labels
bins = [0, 10, 20, 30, 40, 50, 60, float('inf')]
labels = ['Under 10', '10-19', '20-29', '30-39', '40-49', '50-59', '60 and above']

df_customers_copy['AgeRange'] = pd.cut(df_customers_copy['Age'], bins=bins, labels=labels, right=False)

# Creating true copy of df_stores
df_stores_copy = df_stores.copy()
df_stores_copy['StoreAge'] = df_stores_copy['OpenDate'].apply(calculate_age)

# %%
df_customers_copy
# Out:
#        CustomerKey  Gender               Name                 City StateCode  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST        SA
# 1              325  Female       Madison Hull           MOUNT BUDD        WA
# 2              554  Female      Claire Ferres            WINJALLOK       VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER        SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH       VIC
# ...            ...     ...                ...                  ...       ...
# 15261      2099600  Female     Denisa Duková              Houston        TX
# 15262      2099618    Male   Justin Solórzano               Mclean        VA
# 15263      2099758    Male    Svend Petrussen           Wilmington        NC
# 15264      2099862  Female       Lorenza Rush            Riverside        CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township        MI
#
#                    State ZipCode        Country      Continent   Birthday  \
# 0        South Australia    5523      Australia      Australia 1939-07-03
# 1      Western Australia    6522      Australia      Australia 1979-09-27
# 2               Victoria    3380      Australia      Australia 1947-05-26
# 3        South Australia    5223      Australia      Australia 1957-09-17
# 4               Victoria    3698      Australia      Australia 1965-11-19
# ...                  ...     ...            ...            ...        ...
# 15261              Texas   77017  United States  North America 1936-03-25
# 15262           Virginia   22101  United States  North America 1992-02-16
# 15263     North Carolina   28405  United States  North America 1937-11-09
# 15264         California   92501  United States  North America 1937-10-12
# 15265           Michigan   48302  United States  North America 1965-08-18
#
#        Age      AgeRange
# 0       85  60 and above
# 1       44         40-49
# 2       77  60 and above
# 3       66  60 and above
# 4       58         50-59
# ...    ...           ...
# 15261   88  60 and above
# 15262   32         30-39
# 15263   86  60 and above
# 15264   86  60 and above
# 15265   59         50-59
#
# [15266 rows x 12 columns]

# %%
df_stores_copy
# Out:
#     StoreKey        Country                         State  SquareMeters  \
# 0          1      Australia  Australian Capital Territory         595.0
# 1          2      Australia            Northern Territory         665.0
# 2          3      Australia               South Australia        2000.0
# 3          4      Australia                      Tasmania        2000.0
# 4          5      Australia                      Victoria        2000.0
# ..       ...            ...                           ...           ...
# 62        63  United States                          Utah        2000.0
# 63        64  United States                 Washington DC        1330.0
# 64        65  United States                 West Virginia        1785.0
# 65        66  United States                       Wyoming         840.0
# 66         0         Online                        Online           0.0
#
#      OpenDate  StoreAge
# 0  2008-01-01        16
# 1  2008-01-12        16
# 2  2012-01-07        12
# 3  2010-01-01        14
# 4  2015-12-09         8
# ..        ...       ...
# 62 2008-03-06        16
# 63 2010-01-01        14
# 64 2012-01-01        12
# 65 2014-01-01        10
# 66 2010-01-01        14
#
# [67 rows x 6 columns]

# %%
def rename_columns(df, column_mapping):
    existing_columns = set(df.columns)
    rename_dict = {old: new for old, new in column_mapping.items() if old in existing_columns}
    if rename_dict:
        df.rename(columns=rename_dict, inplace=True)

# Define column mappings for each DataFrame
customers_column_mapping = {
    'City': 'City_customer',
    'StateCode': 'StateCode_customer',
    'State': 'State_customer',
    'ZipCode': 'ZipCode_customer',
    'Country': 'Country_customer',
    'Continent': 'Continent_customer'
}

stores_column_mapping = {
    'Country': 'Country_store',
    'State': 'State_store'
}

# Apply the renaming function to the DataFrames
rename_columns(df_customers_copy, customers_column_mapping)
rename_columns(df_stores_copy, stores_column_mapping)

# %% [markdown]
# ### Merge datasets

# %%
df_SalesandStoreMerged = pd.merge(df_sales, df_stores_copy, on='StoreKey', how='left')

# %%
df_SalesStoresProductsMerged = pd.merge(df_SalesandStoreMerged, df_products, on='ProductKey', how='left')

# %%
df_SalesStoresProductsCustomersMerged = pd.merge(df_SalesStoresProductsMerged, df_customers_copy, on='CustomerKey', how='left')

# %%
df_finalMerged = pd.merge(df_SalesStoresProductsCustomersMerged, df_exchange,
                     left_on = ['OrderDate','CurrencyCode'],
                     right_on = ['Date','Currency'],
                     how = 'left')
df_finalMerged.head()
# Out:
#    OrderNumber  LineItem  OrderDate DeliveryDate  CustomerKey  StoreKey  \
# 0       366000         1 2016-01-01   2016-01-01       265598        10
# 1       366001         1 2016-01-01   2016-01-13      1269051         0
# 2       366001         2 2016-01-01   2016-01-13      1269051         0
# 3       366002         1 2016-01-01   2016-01-12       266019         0
# 4       366002         2 2016-01-01   2016-01-12       266019         0
#
#    ProductKey  Quantity CurrencyCode Country_store  ... State_customer  \
# 0        1304         1          CAD        Canada  ...        Ontario
# 1        1048         2          USD        Online  ...     California
# 2        2007         1          USD        Online  ...     California
# 3        1106         7          CAD        Online  ...        Alberta
# 4         373         1          CAD        Online  ...        Alberta
#
#    ZipCode_customer Country_customer  Continent_customer   Birthday Age  \
# 0           N5W 5K6           Canada       North America 1971-03-23  53
# 1             93602    United States       North America 1995-11-20  28
# 2             93602    United States       North America 1995-11-20  28
# 3           T4N 2A6           Canada       North America 1962-08-24  62
# 4           T4N 2A6           Canada       North America 1962-08-24  62
#
#        AgeRange       Date  Currency  Exchange
# 0         50-59 2016-01-01       CAD    1.3884
# 1         20-29 2016-01-01       USD    1.0000
# 2         20-29 2016-01-01       USD    1.0000
# 3  60 and above 2016-01-01       CAD    1.3884
# 4  60 and above 2016-01-01       CAD    1.3884
#
# [5 rows x 37 columns]

# %%
df_finalMerged.drop(columns=['Date', 'Currency'], inplace=True)

# %%
df_finalMerged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrderNumber         62884 non-null  int64
#  1   LineItem            62884 non-null  int64
#  2   OrderDate           62884 non-null  datetime64[ns]
#  3   DeliveryDate        62884 non-null  datetime64[ns]
#  4   CustomerKey         62884 non-null  int64
#  5   StoreKey            62884 non-null  int64
#  6   ProductKey          62884 non-null  int64
#  7   Quantity            62884 non-null  int64
#  8   CurrencyCode        62884 non-null  object
#  9   Country_store       62884 non-null  object
#  10  State_store         62884 non-null  object
#  11  SquareMeters        62884 non-null  float64
#  12  OpenDate            62884 non-null  datetime64[ns]
#  13  StoreAge            62884 non-null  int64
#  14  ProductName         62884 non-null  object
#  15  Brand               62884 non-null  object
#  16  Color               62884 non-null  object
#  17  UnitCostUSD         62884 non-null  float64
#  18  UnitPriceUSD        62884 non-null  float64
#  19  SubcategoryKey      62884 non-null  int64
#  20  Subcategory         62884 non-null  object
#  21  CategoryKey         62884 non-null  int64
#  22  Category            62884 non-null  object
#  23  Gender              62884 non-null  object
#  24  Name                62884 non-null  object
#  25  City_customer       62884 non-null  object
#  26  StateCode_customer  62884 non-null  object
#  27  State_customer      62884 non-null  object
#  28  ZipCode_customer    62884 non-null  object
#  29  Country_customer    62884 non-null  object
#  30  Continent_customer  62884 non-null  object
#  31  Birthday            62884 non-null  datetime64[ns]
#  32  Age                 62884 non-null  int64
#  33  AgeRange            62884 non-null  category
#  34  Exchange            62884 non-null  float64
# dtypes: category(1), datetime64[ns](4), float64(4), int64(10), object(16)
# memory usage: 16.4+ MB

# %%
# Calculating Reveunue Per Customer USD and Profit Per Customer USD

df_finalMerged['RevenueUSD'] = df_finalMerged['Quantity'] * df_finalMerged['UnitPriceUSD']

#  By subtracting the total cost of goods sold from the Revenue USD, to calculate Profit USD

df_finalMerged['ProfitUSD'] = df_finalMerged['RevenueUSD']-(df_finalMerged['Quantity'] * df_finalMerged['UnitCostUSD'])

# %%
# Creating a Frequency Column to the data

# Count the number of orders per customer
order_counts = df_finalMerged.groupby('CustomerKey')['OrderNumber'].count()

# function to Categorize frequency
def categorize_frequency(count):
    if count >= 1 and count <= 4:
        return 'Occasional'
    elif count >= 5 and count <= 10:
        return 'Moderate'
    elif count > 10:
        return 'Frequent'
    else:
        return 'Unknown'

# Apply categorization to get a Series of categories
order_counts_category = order_counts.apply(categorize_frequency)

# Reset index and Merge this frequency information back into the original DataFrame
order_counts_category = order_counts_category.reset_index(name='Frequency')

# Merge with the original DataFrame
df_finalMerged = df_finalMerged.merge(order_counts_category, on='CustomerKey', how='left')

# %%
# maximize display

pd.set_option('display.max_columns', None)

df_finalMerged.head(1)
# Out:
#    OrderNumber  LineItem  OrderDate DeliveryDate  CustomerKey  StoreKey  \
# 0       366000         1 2016-01-01   2016-01-01       265598        10
#
#    ProductKey  Quantity CurrencyCode Country_store State_store  SquareMeters  \
# 0        1304         1          CAD        Canada     Nunavut        1210.0
#
#     OpenDate  StoreAge                      ProductName    Brand  Color  \
# 0 2015-04-04         9  Contoso Lens Adapter M450 White  Contoso  White
#
#    UnitCostUSD  UnitPriceUSD  SubcategoryKey  \
# 0        31.27          68.0             406
#
#                         Subcategory  CategoryKey                Category  \
# 0  Cameras & Camcorders Accessories            4  Cameras and camcorders
#
#   Gender          Name City_customer StateCode_customer State_customer  \
# 0   Male  Tyler Vaught        London                 ON        Ontario
#
#   ZipCode_customer Country_customer Continent_customer   Birthday  Age  \
# 0          N5W 5K6           Canada      North America 1971-03-23   53
#
#   AgeRange  Exchange  RevenueUSD  ProfitUSD Frequency
# 0    50-59    1.3884        68.0      36.73  Moderate

# %%
df_finalMerged.columns
# Out:
# Index(['OrderNumber', 'LineItem', 'OrderDate', 'DeliveryDate', 'CustomerKey',
#        'StoreKey', 'ProductKey', 'Quantity', 'CurrencyCode', 'Country_store',
#        'State_store', 'SquareMeters', 'OpenDate', 'StoreAge', 'ProductName',
#        'Brand', 'Color', 'UnitCostUSD', 'UnitPriceUSD', 'SubcategoryKey',
#        'Subcategory', 'CategoryKey', 'Category', 'Gender', 'Name',
#        'City_customer', 'StateCode_customer', 'State_customer',
#        'ZipCode_customer', 'Country_customer', 'Continent_customer',
#        'Birthday', 'Age', 'AgeRange', 'Exchange', 'RevenueUSD', 'ProfitUSD',
#        'Frequency'],
#       dtype='object')

# %%
df_finalMerged.describe()
# Out:
#         OrderNumber      LineItem                      OrderDate  \
# count  6.288400e+04  62884.000000                          62884
# mean   1.430905e+06      2.164207  2018-11-30 21:21:56.939126016
# min    3.660000e+05      1.000000            2016-01-01 00:00:00
# 25%    1.121017e+06      1.000000            2018-01-25 00:00:00
# 50%    1.498016e+06      2.000000            2019-02-06 00:00:00
# 75%    1.788010e+06      3.000000            2019-11-23 00:00:00
# max    2.243032e+06      7.000000            2021-02-20 00:00:00
# std    4.532963e+05      1.365170                            NaN
#
#                         DeliveryDate   CustomerKey      StoreKey  \
# count                          62884  6.288400e+04  62884.000000
# mean   2018-12-01 20:07:20.582660352  1.180797e+06     31.802144
# min              2016-01-01 00:00:00  3.010000e+02      0.000000
# 25%              2018-01-27 00:00:00  6.808580e+05      8.000000
# 50%              2019-02-07 00:00:00  1.261200e+06     37.000000
# 75%              2019-11-23 00:00:00  1.686496e+06     53.000000
# max              2021-02-27 00:00:00  2.099937e+06     66.000000
# std                              NaN  5.859634e+05     22.978188
#
#          ProductKey      Quantity  SquareMeters  \
# count  62884.000000  62884.000000  62884.000000
# mean    1125.859344      3.144790   1260.640306
# min        1.000000      1.000000      0.000000
# 25%      437.000000      1.000000    840.000000
# 50%     1358.000000      2.000000   1330.000000
# 75%     1650.000000      4.000000   2000.000000
# max     2517.000000     10.000000   2105.000000
# std      709.244010      2.256371    767.739494
#
#                             OpenDate      StoreAge   UnitCostUSD  \
# count                          62884  62884.000000  62884.000000
# mean   2011-05-30 02:16:19.174352896     12.750779    116.253013
# min              2005-03-04 00:00:00      5.000000      0.480000
# 25%              2010-01-01 00:00:00     11.000000     22.050000
# 50%              2010-01-01 00:00:00     14.000000     79.530000
# 75%              2013-06-07 00:00:00     14.000000    138.420000
# max              2019-03-05 00:00:00     19.000000   1060.220000
# std                              NaN      2.933981    140.033327
#
#        UnitPriceUSD  SubcategoryKey   CategoryKey  \
# count  62884.000000    62884.000000  62884.000000
# mean     280.569848      450.198238      4.469611
# min        0.950000      101.000000      1.000000
# 25%       47.950000      303.000000      3.000000
# 50%      181.000000      501.000000      5.000000
# 75%      300.000000      602.000000      6.000000
# max     3199.990000      808.000000      8.000000
# std      382.827515      212.710652      2.132682
#
#                             Birthday           Age      Exchange  \
# count                          62884  62884.000000  62884.000000
# mean   1968-12-05 20:00:44.882641052     55.247599      0.992533
# min              1935-02-04 00:00:00     22.000000      0.672500
# 25%              1952-02-11 00:00:00     38.000000      0.894500
# 50%              1968-11-09 00:00:00     55.000000      1.000000
# 75%              1985-09-24 00:00:00     72.000000      1.000000
# max              2002-01-30 00:00:00     89.000000      1.665200
# std                              NaN     19.402100      0.161601
#
#          RevenueUSD     ProfitUSD
# count  62884.000000  62884.000000
# mean     886.640156    519.411748
# min        0.950000      0.470000
# 25%      115.000000     61.560000
# 50%      360.000000    194.440000
# 75%      969.000000    540.140000
# max    31999.900000  21397.700000
# std     1648.480286   1052.204029

# %%
df_finalMerged.head(5)
# Out:
#    OrderNumber  LineItem  OrderDate DeliveryDate  CustomerKey  StoreKey  \
# 0       366000         1 2016-01-01   2016-01-01       265598        10
# 1       366001         1 2016-01-01   2016-01-13      1269051         0
# 2       366001         2 2016-01-01   2016-01-13      1269051         0
# 3       366002         1 2016-01-01   2016-01-12       266019         0
# 4       366002         2 2016-01-01   2016-01-12       266019         0
#
#    ProductKey  Quantity CurrencyCode Country_store State_store  SquareMeters  \
# 0        1304         1          CAD        Canada     Nunavut        1210.0
# 1        1048         2          USD        Online      Online           0.0
# 2        2007         1          USD        Online      Online           0.0
# 3        1106         7          CAD        Online      Online           0.0
# 4         373         1          CAD        Online      Online           0.0
#
#     OpenDate  StoreAge                             ProductName  \
# 0 2015-04-04         9         Contoso Lens Adapter M450 White
# 1 2010-01-01        14         A. Datum SLR Camera X136 Silver
# 2 2010-01-01        14  Fabrikam Microwave 1.5CuFt X1100 Black
# 3 2010-01-01        14          Contoso SLR Camera M146 Orange
# 4 2010-01-01        14   Adventure Works Laptop8.9 E0890 White
#
#              Brand   Color  UnitCostUSD  UnitPriceUSD  SubcategoryKey  \
# 0          Contoso   White        31.27         68.00             406
# 1         A. Datum  Silver       141.47        427.00             402
# 2         Fabrikam   Black       220.64        665.94             803
# 3          Contoso  Orange       148.08        322.00             402
# 4  Adventure Works   White       166.20        326.00             301
#
#                         Subcategory  CategoryKey                Category  \
# 0  Cameras & Camcorders Accessories            4  Cameras and camcorders
# 1               Digital SLR Cameras            4  Cameras and camcorders
# 2                        Microwaves            8         Home Appliances
# 3               Digital SLR Cameras            4  Cameras and camcorders
# 4                           Laptops            3               Computers
#
#    Gender            Name City_customer StateCode_customer State_customer  \
# 0    Male    Tyler Vaught        London                 ON        Ontario
# 1    Male  Frank Upchurch       Auberry                 CA     California
# 2    Male  Frank Upchurch       Auberry                 CA     California
# 3  Female      Joan Roche      Red Deer                 AB        Alberta
# 4  Female      Joan Roche      Red Deer                 AB        Alberta
#
#   ZipCode_customer Country_customer Continent_customer   Birthday  Age  \
# 0          N5W 5K6           Canada      North America 1971-03-23   53
# 1            93602    United States      North America 1995-11-20   28
# 2            93602    United States      North America 1995-11-20   28
# 3          T4N 2A6           Canada      North America 1962-08-24   62
# 4          T4N 2A6           Canada      North America 1962-08-24   62
#
#        AgeRange  Exchange  RevenueUSD  ProfitUSD   Frequency
# 0         50-59    1.3884       68.00      36.73    Moderate
# 1         20-29    1.0000      854.00     571.06  Occasional
# 2         20-29    1.0000      665.94     445.30  Occasional
# 3  60 and above    1.3884     2254.00    1217.44    Moderate
# 4  60 and above    1.3884      326.00     159.80    Moderate

# %%
df_finalMerged.to_csv("cleaned_datasets/FinalMerged_data.csv")
